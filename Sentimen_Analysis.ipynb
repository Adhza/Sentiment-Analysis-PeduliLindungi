# %%
import string
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()

dataset = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-23ce0b04-9c3c-4275-822e-ed154c55e38c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23ce0b04-9c3c-4275-822e-ed154c55e38c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.csv to dataset.csv

# %%
data = pd.read_csv('dataset.csv')
data.head
# Out:
# <bound method NDFrame.head of                                                comment    VALUE
# 0    Smoga bermanfaat tapi kenapa OTP not Valid...b...  POSITIF
# 1    Menginstal aplikasi ini sama pentingnya dengan...  POSITIF
# 2                      Problem "OTP salah" sudah beres  POSITIF
# 3                          Niat baik harus diapresiasi  POSITIF
# 4    Saya tidak menerima OTP padahal Nomor saya uda...  POSITIF
# ..                                                 ...      ...
# 491                          Ngebug mulu.. nga fungsi!  NEGATIF
# 492                        Force close setelah sign up  NEGATIF
# 493                  Nge lag. Need to fix the bugs ya.  NEGATIF
# 494  apa gunanya kalo setiap aplikasinya di buka ma...  NEGATIF
# 495  Ko force close terus sih. Udh uninstall+instal...  NEGATIF
#
# [496 rows x 2 columns]>

# %%
# proses case folding
import re
def casefolding(comment):
    comment = comment.lower()
    comment = comment.strip(" ")
    comment = re.sub(r'[?|$|.|!²_:")(-+,]', '', comment)
    return comment
data['comment'] = data['comment'].apply(casefolding)
data.head
# Out:
# <bound method NDFrame.head of                                                comment    VALUE
# 0    smoga bermanfaat tapi kenapa otp not validbegi...  POSITIF
# 1    menginstal aplikasi ini sama pentingnya dengan...  POSITIF
# 2                        problem otp salah sudah beres  POSITIF
# 3                          niat baik harus diapresiasi  POSITIF
# 4    saya tidak menerima otp padahal nomor saya uda...  POSITIF
# ..                                                 ...      ...
# 491                             ngebug mulu nga fungsi  NEGATIF
# 492                        force close setelah sign up  NEGATIF
# 493                    nge lag need to fix the bugs ya  NEGATIF
# 494  apa gunanya kalo setiap aplikasinya di buka ma...  NEGATIF
# 495  ko force close terus sih udh uninstallinstall ...  NEGATIF
#
# [496 rows x 2 columns]>

# %%
# proses tokenizing
def token(comments):
    nstr = comments.split(' ')
    dat= []
    a = -1
    for hu in nstr:
        a = a + 1
    if hu == '':
        dat.append(a)
    p = 0
    b = 0
    for q in dat:
        b = q - p
        del nstr[b]
        p = p + 1
    return nstr
data['comment'] = data['comment'].apply(token)
data.head()
# Out:
#                                              comment    VALUE
# 0  [smoga, bermanfaat, tapi, kenapa, otp, not, va...  POSITIF
# 1  [menginstal, aplikasi, ini, sama, pentingnya, ...  POSITIF
# 2                [problem, otp, salah, sudah, beres]  POSITIF
# 3                   [niat, baik, harus, diapresiasi]  POSITIF
# 4  [saya, tidak, menerima, otp, padahal, nomor, s...  POSITIF

# %%
# proses filtering
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

def stopword_removal(comments):
    filtering = stopwords.words('indonesian')
    x = []
    data = []
    def myFunc(x):
        if x in filtering:
            return False
        else:
            return True
    fit = filter(myFunc, comments)
    for x in fit:
      data.append(x)
    return data
data['comment'] = data['comment'].apply(stopword_removal)
data.head(10)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                              comment    VALUE
# 0  [smoga, bermanfaat, otp, not, validbegitu, dik...  POSITIF
# 1  [menginstal, aplikasi, mencuci, tangan, stay, ...  POSITIF
# 2                       [problem, otp, salah, beres]  POSITIF
# 3                                [niat, diapresiasi]  POSITIF
# 4               [menerima, otp, nomor, udah, solusi]  POSITIF
# 5       [i, hope, this, app, will, work, as, it, is]  POSITIF
# 6  [stuck, otp, berulangkali, kirim, otp, diterim...  POSITIF
# 7                                            [hebat]  POSITIF
# 8              [ayo, dukung, program, pemerintah, 1]  POSITIF
# 9  [install, ga, fiturnya, ditambah, odp, /pdp, r...  POSITIF

# %%
# proses stemming
# !pip install Sastrawi
from sklearn.pipeline import Pipeline
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

def stemming(comments):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    do = []
    for w in comments:
        dt = stemmer.stem(w)
        do.append(dt)
    d_clean=[]
    d_clean= " ".join(do)
    print(d_clean)
    return d_clean
data['comment'] = data['comment'].apply(stemming)

data.to_csv('data_clean.csv', index=False)
data_clean = pd.read_csv('data_clean.csv', encoding='latin1')
data_clean.head()
# Out:
# Collecting Sastrawi
#   Downloading https://files.pythonhosted.org/packages/6f/4b/bab676953da3103003730b8fcdfadbdd20f333d4add10af949dd5c51e6ed/Sastrawi-1.0.1-py2.py3-none-any.whl (209kB)
#      |████████████████████████████████| 215kB 5.3MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# smoga manfaat otp not validbegitu kirim sbg partisipan
# menginstal aplikasi cuci tangan stay at home sah physical distancing cepat putus rantai sebar c-19 salam sehat bahagia tuhan yesus kati serta amin
# problem otp salah beres
# niat apresiasi
# terima otp nomor udah solusi
# i hope this app will work as it is
# stuck otp berulangkali kirim otp diterimacoba uninstall verifikasi otp
# hebat
# ayo dukung program perintah 1
# install ga fiturnya tambah odp pdp rumah alarm bunyi  rumah tahu odp pdp jarak 10meter
# good initiative
# good job
# orang goblok yg otak nya serang corona bilang aplikasi ga sesuai harap real-time mapping data rs rujuk lha untuk nya ituso stupid
# semangat developer nya saran tambah peta episentrum covid19 cegah obat semangat developer nya
# apk is the best
# terima kasih upaya cegah sebar covid-19 masalah otp nya tambah 0 awal nomor hp 08111111 tulis 8111111 aja hasil
# nyoba
# it works
# good
# ok
# otp udah fix sih mantapp
# bagus saran aplikasi ielas guna peta poin2 yg sebar odp dll mudah jaga jarak
# verry helpfull app
# ok
# depan fiture akun setting salah nama ganti no hp koreksi ganti
# terimakasih aplikasi ringan insyaallah pakai hampir device orang indonesia pasang pakai memory 12 mbtujuan utama aplikasi capai kumpul data orang dekat ecek bluetooth temu device dicompare guna daftar nomor telepon aktif butuh otp aplikasi maps gps butuh memory  uras batrei jenius
# penasaran bleum pakai user iphone please bikin
# daerah zona merah app pilih daerah aman
# resmi perintah ide kreatif mudah efektif cegah sebar luas
# aplikasi wajib install berantas covid-19
# kebersaaman
# it s works thanks btw otpnya gagal pasti nomer aktif pasti signal gagal otpnya resend codenya
# ok good
# guna kerja sederhana masuk akal
# lets go cap contribute nothing to society
# ngikut warga negara yg btw terima kasih dah bikin aplikasi yg manfaat min
# mohon utk map bara ringkas data dri update odp terahir data positif sembuh tinggal trmksh
# nyobain
# gmn pakenya
# moga guna
# upaya bagus bantu potong rantai tular harap baik kalimat notifikasi potong baca
# guna rakyat indonesia bonus guna
# good
# ok
# ok
# nice
# mantappp
# just advice in app please adding notification history menu it will really help users who don t always see their cellphones tq much
# for humanity for indonesia
# moga putus rantai
# versi ios
# is this mandatory to pdp and odp smartphone are they know
# helping
# tny emg alamat daerah masuk zona merah gmn tuh rumah aja udh 15  krn emg udh karantina mandiri duluan
# manfaat wajib jujur riwayat jalan lupa
# mari bantu perintah informasi sesuai patuh instruksi keluar penting demo esok pesan developer mengupdate data jadi user interfacenya tarik konten relevan tolong serta aplikasi chatbot masyarakat interaksi
# excellent apps to monitor our condition  surrounding
# lawancovid19 lindungikeluarga diamdirumah pakaimasker seringcucitangan
# good
# good job mudah pandemic cepat
# get map
# manfaat
# bagus ide lengkap menu
# awesome
# indonesia
# simple
# manfaat
# aplikasi bagus pwncegahan covid19
# keep improving okay thank you for making this app at least your effort is something that we need to appreciate
# bantu aplikasi yg cerdas i love indonesia
# good aplication
# guys put the app to sleep when its not in use ya atur
# masya allah
# keep on improving
# sinergifightcovid19
# moga bs tau daerah yg rame covid-19
# very good
# good app
# manfaat guna bantu kurang cemas  hindar berita2 hoax covid19
# good
# moga manfaat org
# ok
# gak nyetel musik
# bagus
# good job
# moga manfaat penggguna aplikasi waspada covid-19
# awesome
#
# good info
# niat nya tapimaaf dampak berantas covid 19 syarat mutlak yg penuh 1 hp os android dg fitur bluetooth gps 2 ngerti hp dg 3 hp on 4 orang yg hp peduli instal aplikasi usaha yg bagus yg efektif rang covid 19 5 bintang niat fungsi efektifitas 1 bintang -
# i hope this app can helpful us please register with your real database
#
# rahasia data guna jamin
# bantu
# yesyes
# dar share aplikasi sdh bantu utk ber-hati2 kantor area kel duri kepa jakarta barat tinggal bsd tangerang selatan aplikasi pedulilindungi notifikasi exit tol kbjeruk masuk zona merah yg area tsb positive covid19  pdp  odp zona merah lokasi kantor terima kasih pedulilindungi bantu utk ber-hati2
# good for tracing lokation covid-19
# sbgai upaya lindung
# not perfect but a step to the right direction tambah data informasi2 terupdate covid 19 pop up notifikasi max 2x hari cuci tangan kek minum vitamin kek patuh psbb dll peta sebar opsi rumah bluetooth nyala fitur bahasa orang2 pake bahasa inggris turis yg lg jebak etc
# aplikasi keren bagusmembantu masyarakat indonesia mengasitau zona masuk terikasi tri kominfo
# this is government apps what do you expect more
# trims pedulilindungi
# orang ragu data hp-nya aman aplikasi koneksi bluetooth sosialisasi aplikasi pairing dg hp khawatir data hp nya curi
# guna
# nice app
# ok
# fwel very safe
# good and share to all people
# update error
# smangat berbuatkebaikan
# most power full application
# bagus bantu
# applikasi kyk ny cuman mw tau ada masyarakat drumah ngk dn terap physical distancing ngk gk yg dlm gang yg pd nongkrong bubarin
# good information but infected food is more dangerous than infected person
# good application
# terimakasih
# ok
# bitang
# nice apps
# aplilasi bagus zona merah aman
# can not work
# terimakasih
# bantu
# bagus banget bantu update aplikasi tutup
# oke
# bismillahirohmanirrohiim
# the best
# it s wonderful app guys
# thanks kominfo
# good apps guna
# bagussss
# download
# very good
# update keluar2
# ok
# terimakasih bantu layan nya
# good aplication
# bug hp xiaomi 21 april 2020
# ok
# good
# tambah fitur map area jauh terimakasih
# tambah info copid 19
# hanis update error ya
# stlah update error
# buka langsung hilang tolong benahin ya
# cool
# it s very good intention good idea good effort so far the government did well but this app is switching off by it self please fix the problem
# update stop working ya
# cool
# lumayan upaya cegah
# gps nyala app force to stop
# good
# aplikasi guna device force close mohon depan baik
# good
# bagus sih cuman force closed ama servernya blm akses byk orng
# after i update but why always close it just close app or send feedback
# manfaat putus rantai covid-19
# keren
# bagus waspada
# ok sdg ganggu ya muncul notice nya cepet banget lsg ilang
# update fitur force close
# good
# bantu situasi inisemoga wabah cepat
# keren
# gagal verifikasi otp
# tambahin fitur maps fungsiin tukar data live location sebar biar bener2 tau kawasan bahaya covid19 min
# nomor udah bener otp nggak dateng2
# aplikasi dilaunching dlu masuk aja g invalid otp terima kasih otp sdh dperbaiki
# tukar informasi bluetooth menshare lokasi perangkat resiko aman perangkat bantu lingkung moga kembang depan
# saran kasih ingat alarm 2 device orang - sesuai physical distancing
# uda bagus aplikasi tp hny fungsi maksimal klo byk org yg pakai sosialisasi pakai iklan tv smakin byk org yg peduli pakai aplikasi
# odp orang awas sih orang pantau
# sosis ikan telur fitur konfigurasi dg google maps meta zona merah so daerah
# fungsi sy blm info sebar wilayah infeksi dll tp sy biar terinstall bluetooth on asumsi apps data statistik olah keluh otp masuk tampil countdown utk nunggu kode otp kirim dlm 10-15detik tdk terima klik ikon back trus lg utk kirim ulang otp sy coba kode otp langsung terima
# i found that this app has impacted mobile hotspot feature it made the hotspot become intermittent and no easy to reconnect a device into hotspot
# otp terima verifikasi lancar
# login lancar notifikasi zone update 24 jam ubah
# this app is getting much better now the only thing left don t use bluetooth connection it s weird social media app such like ig twitter others can track its user just from location and no need bluetooth connection at all so i will give 5 stars if this app doesn t need bluetooth connection thanks
# alangkah baik aplikasi langsung automatic download gadget applikasi tsb
# fitur peta
# pasien positif covid19 wajib pasang aplikasi positif pdp odp database pedulilindungi moga jalan lancar sesuai rencana
# tambah media edukasi konsep ide kerja apps nya deskripsi preview play store model tulis video
# lbh mapping yg trace virus
# notifikasi restart handphone notifikasi ikut instruksi restart muncul notifikasi
# full of potential need more advanced featuresmaps alert when surrounded by other people using the same appsetc
# teori bagus informatif alangkah baik lengkap data dukung peta infografis berita tekan tombol update proses jam update ubah
# partisipasi tp tolong tambahin peta wilayah aktual yg merah hijau dsb
# history berubah2 tanggal yg kadang merah kadang aman merah merah dr sampe aman ubah aman pemberitahuan zona muncul notifikasi
# aplikasi bagus data mana yg redzone data screening covid-19 akurat terima kasih
# oke
# top
# tarik sih cuman kalo lokasi di-update real-time bikin boros batere ya  kasih bintang 4 update lokasi di-trigger pas sambung perangkat pedulilindungi  oke
# hi devs aplikasi bagus sayang tarik nyala bluetooth krn cepat battery drain jadi bluetooth sbg opsional krn lokasi dgn gps internet akurat tdk hape masyarakat tingkat mid - high end pilih utk tentu lokasi manual gps mngkin tdk fungsi dgn hape aplikasi tampil x dgn zona a b c that s it semangat ya
# ad pilih pilih lokasi
# ok
# interesting appbut is it effective in the field i mean is not just an app but usefull
# mohon peta nya real time sih akurasi 10 meter lingkar gimana red zone kosan wfh ga
# kali susah update
# guna utk zona hijau sedanh masih zona merah
# try it now
# alangkah baik guna informasi orang yg konfirmasi covid 19 odp lokasi milik hp
# tolong bluetooth nya nggak udah hidup habis days baterai aktif terus mudah jalan hacking moga saran dengar
# mantal
# sharenya mohon diperbanya igfbtelegram dll terkoneksj
# inisiatif konsep bagus optimal fitur mana guna mengupdate status odp positif update dr situ kirim notifikasi guna kontak shg langsung ambil langkah tangan karantina mandiri mohon timbang
# whatever works
# it s like pok mon go but when your phone ringing you better be more careful anyway can you please add mapping for red zone
# good
# baik pilih guna gps bluetooth interval versi gps bluetooth always on hp baterai cepat habis moga apps manfaat
# good
# tuju manfaat aplikasi bagus terap negera 62 sulit jalan karakter orang yg ngeyel gak peduli moga depan virus jelek ssgera salam sehat
# yg komen pake bahasa indonesia aja kalee developer orang endonesah gk kerja silicon valley eet dah
# still try to follow
# good
# range zona merah yg luas lurah yg data oleh data lokasi app notif red zone  kecil range nya wilayah rt
# ko update manual ya ga auto update android 10 aplikasi
# oke alert pasuk danger zone
# i hope this application is useful
# i know its not complete and perfect yet but at least we support our government and this one of their improvement to againts covid-19 in this country one step ahead thx indonesia i respect
# coba
# kasih bintang 4 informasi - ada lurah - data infeksi zona merah - terang arti warna - tambah peta guna tau area zona merah - panic button butuh bantu darurat hubung 119 ext 9 - boros baterai aktif location bluetooth - ui interaktif
# fitur bluetooth fungsi bikin hp boros batre plus rentan hack
# sorry pakai aplikasi peduli lindung kalo ngaruh wifi kalo konek pakai wifi koneksi hp ganggu putus2 banget kalo pakai paket data data ngak papa puter youtube wifi putus2 banget barusan coba uninstall konek youtube pakai wifi lancar jaya hp konek 2 hp pakai aplikasi masalah 1 hp uninstall atas
# alangkah map detail posisi positif covid pdp
# force close update versi baru
# app nya crash min huawei p30 pro
# helpfull
# update baru eror yaa masuk aplikasi
# force close please fix this
# metodologi nya gmn dlm deteksi zona merah
# sempet crash normal update data karna based on peta daerah wilayah kuning merah
# bagus bantu sayang aplikasi force closed
# versi update jalan
# lurah nya gak yaa cm up date adik nama lurah nya
# tunggu 1-2 benar2 aktif krn tunggu daftar resmi dlm database  lebih tunggu mutakhir  terima kasih
# buka lgsg hilang
# i m repeatedly being told that i m in the red zone and i should move my home is in the red zone what do you expect and no option to turn off the annoying red zone notification and also repeated forced close i understand this app is for contact tracing but many people don t instead of adding more features that will eat more space why don t make installation of this app obligatory for all citizen
# application forced to closed after last update kindly need your help to fix it thanks
# aplikasi konsep bagus versi hasil 1x jalan close alami force close
# so far so good
# aplikasi suka crash ga buka install ulang
# good monitoring position
# apps terus crash stopped fungsi bluetooth ya
# apps crashed after i opened it
# crash buka smenjak update
# aplikasi error forced closed tba2 mohon dperbaiki xiaomi note 8 samsung a7
# force close ya
# update crash running app tolong follow-up yah dev
# bug after update aplikasi force close
# it keeps stopping after latest updates
# not compatible samsung s7 edge
# update crash pocophone f1
# ga dipake
# force close can t open on redmi 4a fix it please as soon as posible thx
# app always suddently crash
# everytime i try to open it it s closed immediately whenever i need the information from this apps i should uninstall and reinstall again and all over again  so sad
# habis masuk apps henti
# ga akses registrasi app nya ga buka
# update barusan force close
# mendownload regristrasi aplikasi coba 3x hasil nihil tolong baik orang paksa informasi partisipasi data sebar
# app keeps stopping
# check hp root cheker deteksi root ehh pas buka aplikasi deteksi root
# pedulilindungi keep stopping gitu kayak aplikasi gimmick
# update crash
# turn on location aplikasi langsung tutup suruh turn on location please troubleshoot
# versi 200 bagus fitur tampil cantik menit crash masuk
# when im open after download it keeps stopping
# buka aplikasi force close
# daftar apps nya langsung ga buka close mulu
# aplikasi tiba henti
# masuk otp nyalain location bluetooth keep stopping teroooos
# ga buka latest update auto crash
# jalan 1 force closed begiti aplikasi jalan
# crash update reinstall crash note 5
# gak buka
# aplikasi force closed
# diupdate gk buka
# update nya keep close apps baik android 10 galaxy a7 2018
# aplikasi crash gps aktif
# useless app keep crashing
# end task after registered and cant running again
# aplikasi crash buka registrasi force close
# gimana cerita notifikasi terima buka aplikasi crash total - sumpah mampus ane bingung
# bagus updatetan gak fungsi sih sistem unistall install ulang gak masuk sempurna update gak update masuk detik langsung aplikasi aplikasi log out gak restart tolong baik pakai hp android
# awwlnya bagus gak buka buka aplikasi langsung force close uninstall deh
# aps keeps stopping
# when i touch the notification it crashes and i can t open the app anymore please fix it
# crash
# internet bagus aktif otp notifikasi no internet connection
# mati buka appsnya udah update benerin gih
# application stpp and error occurs
# aplikasi error
# force close for new update we need a map not only the district zone
# et dah buka langsung nutup
# the app is automatically forced close so i can t use this apps please fix it
# aplikasi force close melulu nggak
# aplikasi tutup
# cant use
# hang update
# update sktr 11 jam skg aplikasi buka 2 detik aplikasi tutup kayak yg salah
# aplikasi nutup daftar pakai aplikasi apaaa klo bantu tolong baik jangan2 ambil data orang2 yg daftar
# masuk pas masuk aplikasi nya engga tolong benar
# forced close
# ga
# app nya ngecrash sih notifikasi ttp masuk tpi app nya gabisa buka lgsg homescreen  pdhal excited bgt sm app
# erorr
# bug d update baru force close
# the application keeps stopping i don t know why can t even get the information i need
# force close redmi note 8 pro
# don t not open
# crash teroooos gabisa buka ngapa kali
# tgl 20 apr 20 coba diupdate error app-nya ga
# keep on crashing after last updatem uninstall then reinstall still the same restart phonestill the same fix pleasedraining battery
# udah install log in macem eh aplikasi force stop mulu
# aplikasi crash mohon baik
# langsung eror stop buka alagi
# kemaren green zone hari red zone psbb bikin red zone update knp lsg forced closed
# keep crashing
# gak 6x buka crashed muluk uninstall
# crash  please update this app
# auto close aplikasi tolong baik
# masuk crash tolong baik
# root g ribbet
# not working always stop
# force closed baik
# kasih 1 ga buka aplikasi daftar masuk aplikasi langsung
# keep crashing
# aplikasi ngebug tarus closed
# app crash after update to 20 ver
# aplikasi henti
# update aplikasi mati
# get always stop app
# install hp xiaomi sengaja install hp krn hp baterenya boros tp xiaomi terus2an crash
# update malam appnya crash terus gabisa buka bintang 5 app normal update
# keep crashing in my redmi note 8 pro indonesia 6 128 thank you
# update
# gabisa dipake buka aplikasi
# buka homescreen gak pakai
# after i update i couldn t open it anymore please fix this
# applikasinya crash smartphone buka
# beranda force closed tolong baik unistall
# ga daftar udah masukin nama  no hp ngeklik kirim otp muncul alert isi nya hpku ga koneksi internet nya udah kirim otp masuk aplikasi stopping tolong baik
# ga bs buka aplikasi yg bs diliatpdhl uda aktifin bluetooth gps
# tgl 21 april 2020 update telah aplikasi fungsi wajar restart perangkat aplikasi jalan mohon baik
# aplukasu ganggu
# force close mulu
# error message when opening the app keeps stoping android v 70 please fix it
# ayo kominfo semangat update aplikasi yg guna status error bs
# update 22 april aplikasi tutup buka
# this apps keep crash
# force close serius niat ngga sih bikin app or just another wasting money it force closes everytime opening the app after successful download
# keep force close
# after update the application becomes auto stopped horribly
# update aplikasi g buka hape xiaomi
# uninstall aplikasi jelek force closed
# to slow
# force close update
# error daftar closes terur tutup
# buka langsung nutup otomatis doesn t work
# force close
# crash diinstal
# forced close
# aplikasi parah
# forceclose
# app auto stop
# aplikasi buka mucul notifikasi aplikasi stopped working
# appsnya nge crash mulu gmna dah
# buka uninstal instal ulang kagol
# forced close uninstall reinstall otp kirim blokir
# crash on vivo v7
# registrasi sesuai prosedur dr aplikasi masuk aplikasi langsung aplikasi dgn notif pedulilindungi keeps stopping mohon ditindaklanjuti terima kasih
# habjs update crash ga launch aplikasi
# haven t try all the features the app keep on crashing also is there any need of bluetooth connection
# diupdate aplikasi akses langsung close app
# crash all the time
# aplikasi nya kadang buka ga tiba2 tutup ya
# mati mati ya
# update baru force close mohon baik
# crash force close gps aktif
# the application was unable to start correctly it always force to close everytime i open it please fix and update the application thank you
# useless app error while i tried to open
# crash mulu buka buset dah
# the app crash constantly
# restart melulu
# application continously stopped on samsung a8p
# buka aplikasi mohon baik aplikasi baterai akibat bluetooth location gps devicesamsung galaxy s8
# gagal gabung henti muter muter tunggu otp
# update aplikasi buka force close
# applikasi stop buka stop buka stpp bgmn mo lihat notif buka stop perbakki ya
# force closed
# always forceclose
# upgrade d upgrade buka apps forced quit tambah info brp org yg positif pdp odp tinggal d daerah terserbut tracking place mrk mana contoh aplikasi korsel
# jelek bluetooth lokasi aktif crash lokasi yg aktif loadingnya lambat mutu
# force close after register dear admin please fix it
# aplikasi pakai send feedback close app fungsi
# great app zero outcome
# ideenya bagus praktek nul app crash melulu pakai
# abis update 21 04 2020 force close kyknya gak kompetibel android q
# app always crash
# ngak jalan oppo a83 update
# crash melulu
# gk bs buka
# apps error gak buka nokia 32 plus android 9
# force closed
# aplikasi nya keep stoping mi 8 lite
# tutup diuninstal diinstal
# force close  hasil daftar aplikasi
# install udah registrasi utk masuk beranda gagal reset lagiberulang 3 kali uninstall
# hp ngga diroot tp deteksi diroot payah
# perangkat root aplikasi initerdeteksi perangkat dirootcuman aplikasi tanda daerah covid ga root klo hape ga root nyuri data pribadiaga curiga sihuntung hape root wkwkwkwkwkw
# force close
# versi baru stabil aktif fitur lokasi force close
# masuk aplikasi
# aplikasi crash
# update sore tanggal 21 april 2020 buka aplikasi lgsg forced close ga buka clear cache re install tetep
# crashhhpakkkk mental
# bad app always not responding
# cannot working has been download but i can t open the app pls improve
# error melulu pas buka langsung close
# it was nice to know there s an useful apps related to covid -19 specifically when we are at a red zone or in a crowd our mobile will beep then i installed it but at some other time when i tried to open the apps it does not work the apps closed directly anyway i don t know if it s really useful or not
# it keeps crashing it wont open
# update aplikasi baru hp xiaomi samsung oppo vivo buka aplikasi langsung tutup ada solusi
# nokia 6 android ver 9 - aplikasi force close gps aktif tunggu baik terima kasih
# update versi buka force close
# can t use this app because it force to close this app really need to fix
# error pedulilindungi keeps stoping send bug for analysis gua min
# aplikasi langsung close hadehh sebal
# data akurat boros baterai apps langsung close buka
# program hang
# selesai instalasi isi data otp habis aplikasi langsung close otomatis coba close otomatis fungsi redmi note 7
# force close
# force close app beg
# crash and not open
# keep force closed please fix it
# always force closed after update
# error appnyahabis masuk
# when i opened the application it will be closed
# peduli lindung hp yg root pakai app
# berkali2 stop working gak dipake udah instal ulang gitu pake xiaomi note 7
# yikes everytime i tried to open this app it kept force closing
# bagus fungsi tampil nya bagus aneh ubah zona kuning aplikasi nya force close clear cache clear data ya gitu uninstall install ya aja force closed ga gitu tolong dibenerin aplikasi efektif selamat nyawa
# otp went smooth this app only show our current location no clue whether valid or not is a red green zone add map please and fix your empty string bug it only worked once and keep force closing afterwards one more thing why on earth you need bluetooth for
# forced close meluluuuu
# force closed melulu
# instal  app keeps stopping  gmn ni
# force close
# hbz diupdate tiba2 crash app nya ga buka lg stlh tu mnta tlg dibenerin makasih
# crash
# aplikasi stabil force close bug baik baik aplikasi
# force closed ga pakai
# baik error buka
# the app keeps closing itself anytime i open it
# abis update jd force close hadeuhh
# 1 detik buka langsung forced-closed xiaomi redmi note 4x
# aplikasi stop working ga buka
# crash bangg masukkapps nya tolong d perbaikisekedar infosaya pk vivo v15pro
# buka
# buka kagak kentang kali
# close everytime i open the app i haven t even check anything
# why it keeps forced close
# ga buka crash
# it keeps stoping meh
# download tdk bs buka kecewa
# crash hp
# update aplikasi force close
# buka langsung tutup kembalijadi app
# can t open the app after the last update on my oneplus 7 pro device with the latest android version
# sdh up load mati2 trus ga open knapa  deteksi yg covid19 skitar lingkung sy
# something wrong with the application every time i opened it it was suddenly closed i could not say this application is useful
# ponselnya diroot pakai aplikasi kemarin
# fungsi device force close tolong baik
# bintang 1 krn app crash app tdk buka auto exit buka hp xiaomi 2 prime
# aplikasi nya henti
# mati mati mulu nutup klw pindah lokasi
# crash application
# app keeps stopping end up not being used at all
# diupdate buka aplikasi nya
# update baru crash aplikasi terclose
# can t run
# always force close unable to update i use xiaomi mi 8 lite
# force close all the time
# error
# stop aplikasi
# force close aplikasi coba buka langsung close wkwk tolong baik alat bantu vital tambah fitur jalan fitur2
# pakai update  4x  buka aplikasi nya force close
# aplikasi g crash program doang
# semenjak diupdate nutup aplikasi aneh tampil informatiftolong baik aplikasi bantu
# error android hp mi6 mi8  blm
# always force closed i can t open this app
# app has stop on start
# aplikasi force stop mulu
# ngebug mulu nga fungsi
# force close sign up
# nge lag need to fix the bugs ya
# guna kalo aplikasi buka nutup share temen2
# ko force close sih udh uninstallinstall lg ulang kali tetep aja buka trus nutup udh reboot salah ya
#                                              comment    VALUE
# 0  smoga manfaat otp not validbegitu kirim sbg pa...  POSITIF
# 1  menginstal aplikasi cuci tangan stay at home s...  POSITIF
# 2                            problem otp salah beres  POSITIF
# 3                                     niat apresiasi  POSITIF
# 4                       terima otp nomor udah solusi  POSITIF

# %%
data_clean = data_clean.astype({'VALUE' : 'category'})
data_clean = data_clean.astype({'comment' : 'object'})
data_clean.dtypes
# Out:
# comment      object
# VALUE      category
# dtype: object

# %%
# proses TF-IDF
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

tvec = CountVectorizer()
X_cVec = tvec.fit_transform(data_clean['comment'].values.astype('U'))
print(X_cVec)
h_tfidf = TfidfTransformer()
x_tfidf = h_tfidf.fit_transform(X_cVec)
print(x_tfidf)
X = data_clean.comment
Y = data_clean.VALUE
# Out:
#   (0, 1017)	1
#   (0, 656)	1
#   (0, 815)	1
#   (0, 761)	1
#   (0, 1201)	1
#   (0, 575)	1
#   (0, 963)	1
#   (0, 834)	1
#   (1, 685)	1
#   (1, 86)	1
#   (1, 254)	1
#   (1, 1072)	1
#   (1, 1038)	1
#   (1, 109)	1
#   (1, 449)	1
#   (1, 953)	1
#   (1, 864)	1
#   (1, 303)	1
#   (1, 212)	1
#   (1, 899)	1
#   (1, 909)	1
#   (1, 969)	1
#   (1, 10)	1
#   (1, 955)	1
#   (1, 973)	1
#   :	:
#   (493, 192)	1
#   (494, 86)	1
#   (494, 414)	1
#   (494, 992)	1
#   (494, 193)	1
#   (494, 544)	1
#   (494, 771)	1
#   (494, 1086)	1
#   (495, 954)	1
#   (495, 45)	1
#   (495, 999)	1
#   (495, 1168)	2
#   (495, 1249)	1
#   (495, 621)	1
#   (495, 193)	1
#   (495, 376)	1
#   (495, 221)	1
#   (495, 1148)	1
#   (495, 1170)	1
#   (495, 542)	1
#   (495, 582)	1
#   (495, 771)	1
#   (495, 1105)	1
#   (495, 1175)	1
#   (495, 913)	1
#   (0, 1201)	0.41077196846732394
#   (0, 1017)	0.41077196846732394
#   (0, 963)	0.3852090551625894
#   (0, 834)	0.41077196846732394
#   (0, 815)	0.2656034152874563
#   (0, 761)	0.2758495677233932
#   (0, 656)	0.29780887729402544
#   (0, 575)	0.3317903976375944
#   (1, 1252)	0.23001857340234597
#   (1, 1154)	0.23001857340234597
#   (1, 1072)	0.2055479841561404
#   (1, 1038)	0.23001857340234597
#   (1, 988)	0.21570419632276533
#   (1, 973)	0.21570419632276533
#   (1, 969)	0.17691922999697912
#   (1, 955)	0.21570419632276533
#   (1, 953)	0.23001857340234597
#   (1, 909)	0.19767021397933826
#   (1, 899)	0.2055479841561404
#   (1, 864)	0.2055479841561404
#   (1, 685)	0.23001857340234597
#   (1, 550)	0.23001857340234597
#   (1, 449)	0.21570419632276533
#   (1, 303)	0.2055479841561404
#   (1, 254)	0.21570419632276533
#   :	:
#   (493, 192)	0.44657796885025985
#   (494, 1086)	0.49748330869488355
#   (494, 992)	0.44455840996237267
#   (494, 771)	0.3916335112298618
#   (494, 544)	0.44455840996237267
#   (494, 414)	0.32971534900389476
#   (494, 193)	0.2365245344277575
#   (494, 86)	0.1980230389631146
#   (495, 1249)	0.18053110493322888
#   (495, 1175)	0.2688317330167584
#   (495, 1170)	0.21714185592566598
#   (495, 1168)	0.5042039176115041
#   (495, 1148)	0.2402319951012827
#   (495, 1105)	0.25210195880575204
#   (495, 999)	0.20242519804440012
#   (495, 954)	0.23102493595987578
#   (495, 913)	0.2688317330167584
#   (495, 771)	0.21163225718580705
#   (495, 621)	0.23102493595987578
#   (495, 582)	0.25210195880575204
#   (495, 542)	0.2235022208902764
#   (495, 376)	0.12394290991324189
#   (495, 221)	0.12394290991324189
#   (495, 193)	0.12781393743240965
#   (495, 45)	0.21714185592566598

# %%
# splitting data
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

kf = KFold(n_splits=10)
X_array = x_tfidf.toarray()
def cross_val(estimator):
  acc = []
  pcs = []
  rec = []

  for train_index, test_index in kf.split(X_array, Y):
    X_train, X_test = X_array[train_index], X_array[test_index]
    y_train, y_test = Y[train_index], Y[test_index]

    model = estimator.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc.append(accuracy_score(y_test, y_pred))
    pcs.append(precision_score(y_test, y_pred, average='macro', zero_division=0))
    rec.append(recall_score(y_test, y_pred, average='macro', zero_division=0))
    rec.append(f1_score(y_test, y_pred, average='macro', zero_division=0))

    print(classification_report(y_test, y_pred, zero_division=0))
    print(f'confusion matrix:\n {confusion_matrix(y_test, y_pred)}')
    print('================================================\n')

  print(f'average Akurasi: {np.mean(acc)}')
  print(f'average Presisi: {np.mean(pcs)}')
  print(f'average recall: {np.mean(rec)}')
  print(f'average f1-score: {np.mean(rec)}')

from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
cross_val(nb)
# Out:
#               precision    recall  f1-score   support
#
#      NEGATIF       0.00      0.00      0.00         0
#      POSITIF       1.00      0.66      0.80        50
#
#     accuracy                           0.66        50
#    macro avg       0.50      0.33      0.40        50
# weighted avg       1.00      0.66      0.80        50
#
# confusion matrix:
#  [[ 0  0]
#  [17 33]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       0.00      0.00      0.00         0
#      POSITIF       1.00      0.62      0.77        50
#
#     accuracy                           0.62        50
#    macro avg       0.50      0.31      0.38        50
# weighted avg       1.00      0.62      0.77        50
#
# confusion matrix:
#  [[ 0  0]
#  [19 31]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       0.00      0.00      0.00         0
#      POSITIF       1.00      0.54      0.70        50
#
#     accuracy                           0.54        50
#    macro avg       0.50      0.27      0.35        50
# weighted avg       1.00      0.54      0.70        50
#
# confusion matrix:
#  [[ 0  0]
#  [23 27]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       0.00      0.00      0.00         0
#      POSITIF       1.00      0.62      0.77        50
#
#     accuracy                           0.62        50
#    macro avg       0.50      0.31      0.38        50
# weighted avg       1.00      0.62      0.77        50
#
# confusion matrix:
#  [[ 0  0]
#  [19 31]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       0.07      1.00      0.13         2
#      POSITIF       1.00      0.44      0.61        48
#
#     accuracy                           0.46        50
#    macro avg       0.53      0.72      0.37        50
# weighted avg       0.96      0.46      0.59        50
#
# confusion matrix:
#  [[ 2  0]
#  [27 21]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       1.00      0.92      0.96        50
#      POSITIF       0.00      0.00      0.00         0
#
#     accuracy                           0.92        50
#    macro avg       0.50      0.46      0.48        50
# weighted avg       1.00      0.92      0.96        50
#
# confusion matrix:
#  [[46  4]
#  [ 0  0]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       1.00      0.92      0.96        49
#      POSITIF       0.00      0.00      0.00         0
#
#     accuracy                           0.92        49
#    macro avg       0.50      0.46      0.48        49
# weighted avg       1.00      0.92      0.96        49
#
# confusion matrix:
#  [[45  4]
#  [ 0  0]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       1.00      0.88      0.93        49
#      POSITIF       0.00      0.00      0.00         0
#
#     accuracy                           0.88        49
#    macro avg       0.50      0.44      0.47        49
# weighted avg       1.00      0.88      0.93        49
#
# confusion matrix:
#  [[43  6]
#  [ 0  0]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       1.00      0.92      0.96        49
#      POSITIF       0.00      0.00      0.00         0
#
#     accuracy                           0.92        49
#    macro avg       0.50      0.46      0.48        49
# weighted avg       1.00      0.92      0.96        49
#
# confusion matrix:
#  [[45  4]
#  [ 0  0]]
# ================================================
#
#               precision    recall  f1-score   support
#
#      NEGATIF       1.00      0.94      0.97        49
#      POSITIF       0.00      0.00      0.00         0
#
#     accuracy                           0.94        49
#    macro avg       0.50      0.47      0.48        49
# weighted avg       1.00      0.94      0.97        49
#
# confusion matrix:
#  [[46  3]
#  [ 0  0]]
# ================================================
#
# average Akurasi: 0.7473061224489796
# average Presisi: 0.503448275862069
# average recall: 0.42480158420328007
# average f1-score: 0.42480158420328007
